# %%
from ase.build import fcc100, add_adsorbate, molecule
from ase.optimize import LBFGS
from fairchem.core import pretrained_mlip, FAIRChemCalculator
from huggingface_hub import login

# Hugging Face에 로그인 (gated repository 접근을 위해 필요)
# hf auth login 으로 이미 로그인했으면, 저장된 토큰을 사용합니다
# 로그인이 안 되어 있다면 login() 실행 시 토큰을 입력하라는 프롬프트가 나타납니다
try:
    login()  # 저장된 토큰 사용 (터미널에서 hf auth login으로 로그인한 경우)
except:
    print("로그인이 필요합니다. hf auth login을 실행하거나 아래 주석을 해제하여 토큰을 직접 입력하세요")
    # login(token="your_token_here")  # 토큰을 직접 입력하려면 이 줄의 주석을 제거하세요

predictor = pretrained_mlip.get_predict_unit("uma-s-1p1", device="cuda")
calc = FAIRChemCalculator(predictor, task_name="oc20")

from ase.io import write,read
from ase.visualize import view

struct_path = "/home/minkyu/EfficientCatGen/generated_structures/structure_000000.cif"
struct = read(struct_path)

struct.calc = calc

# Set up LBFGS dynamics object
opt = LBFGS(struct)
opt.run(0.05, 100)
# Out:
#        Step     Time          Energy          fmax
# LBFGS:    0 09:33:22     -241.065560       12.814874
# LBFGS:    1 09:33:48     -296.084626        6.503064
# LBFGS:    2 09:34:13     -304.691484        3.730704
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 28
#      26 # Set up LBFGS dynamics object
#      27 opt = LBFGS(struct)
# ---> 28 opt.run(0.05, 100)
#
# File ~/micromamba/envs/eff_cat_gen/lib/python3.10/site-packages/ase/optimize/optimize.py:417, in Optimizer.run(self, fmax, steps)
#     402 """Run optimizer.
#     403
#     404 Parameters
#    (...)
#     414     True if the forces on atoms are converged.
#     415 """
#     416 self.fmax = fmax
# --> 417 return Dynamics.run(self, steps=steps)
#
# File ~/micromamba/envs/eff_cat_gen/lib/python3.10/site-packages/ase/optimize/optimize.py:286, in Dynamics.run(self, steps)
# ...
